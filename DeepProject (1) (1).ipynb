# %%
# !mkdir -p ~/.kaggle && echo KGAT_e382b66919744406c252810e86733f1e > ~/.kaggle/access_token && chmod 600 ~/.kaggle/access_token

# %%
# !export KAGGLE_API_TOKEN=KGAT_302c4bd2575c0d83b1a45d1947f902e2 # Copied from the settings UI

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content"
# !kaggle competitions download -c beyond-visible-spectrum-ai-for-agriculture-2026
# !unzip beyond-visible-spectrum-ai-for-agriculture-2026.zip
# Out:
# Downloading beyond-visible-spectrum-ai-for-agriculture-2026.zip to /content
# 100% 191M/191M [00:01<00:00, 164MB/s]
#
# Archive:  beyond-visible-spectrum-ai-for-agriculture-2026.zip
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_1.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_10.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_100.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_101.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_102.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_103.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_104.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_105.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_106.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_107.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_108.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_109.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_11.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_110.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_111.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_112.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_113.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_114.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_115.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_116.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_117.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_118.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_119.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_12.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_120.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_121.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_122.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_123.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_124.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_125.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_126.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_127.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_128.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_129.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_13.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_130.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_131.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_132.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_133.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_134.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_135.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_136.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_137.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_138.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_139.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_14.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_140.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_141.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_142.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_143.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_144.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_145.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_146.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_147.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_148.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_149.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_15.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_150.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_151.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_152.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_153.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_154.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_155.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_156.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_157.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_158.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_159.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_16.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_160.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_161.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_162.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_163.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_164.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_165.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_166.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_167.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_168.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_169.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_17.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_170.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_171.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_172.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_173.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_174.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_175.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_176.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_177.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_178.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_179.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_18.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_180.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_181.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_182.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_183.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_184.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_185.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_186.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_187.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_188.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_189.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_19.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_190.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_191.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_192.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_193.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_194.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_195.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_196.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_197.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_198.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_199.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_2.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_20.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_200.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_21.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_22.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_23.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_24.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_25.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_26.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_27.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_28.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_29.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_3.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_30.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_31.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_32.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_33.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_34.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_35.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_36.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_37.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_38.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_39.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_4.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_40.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_41.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_42.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_43.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_44.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_45.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_46.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_47.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_48.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_49.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_5.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_50.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_51.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_52.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_53.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_54.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_55.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_56.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_57.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_58.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_59.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_6.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_60.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_61.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_62.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_63.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_64.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_65.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_66.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_67.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_68.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_69.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_7.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_70.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_71.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_72.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_73.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_74.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_75.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_76.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_77.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_78.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_79.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_8.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_80.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_81.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_82.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_83.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_84.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_85.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_86.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_87.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_88.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_89.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_9.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_90.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_91.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_92.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_93.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_94.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_95.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_96.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_97.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_98.tif
#   inflating: Kaggle_Prepared/train/HS/Health_hyper_99.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_1.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_10.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_100.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_101.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_102.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_103.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_104.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_105.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_106.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_107.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_108.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_109.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_11.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_110.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_111.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_112.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_113.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_114.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_115.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_116.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_117.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_118.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_119.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_12.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_120.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_121.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_122.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_123.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_124.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_125.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_126.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_127.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_128.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_129.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_13.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_130.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_131.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_132.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_133.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_134.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_135.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_136.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_137.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_138.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_139.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_14.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_140.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_141.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_142.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_143.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_144.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_145.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_146.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_147.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_148.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_149.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_15.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_150.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_151.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_152.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_153.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_154.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_155.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_156.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_157.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_158.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_159.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_16.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_160.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_161.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_162.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_163.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_164.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_165.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_166.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_167.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_168.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_169.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_17.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_170.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_171.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_172.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_173.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_174.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_175.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_176.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_177.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_178.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_179.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_18.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_180.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_181.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_182.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_183.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_184.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_185.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_186.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_187.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_188.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_189.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_19.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_190.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_191.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_192.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_193.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_194.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_195.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_196.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_197.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_198.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_199.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_2.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_20.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_200.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_21.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_22.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_23.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_24.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_25.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_26.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_27.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_28.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_29.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_3.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_30.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_31.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_32.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_33.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_34.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_35.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_36.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_37.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_38.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_39.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_4.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_40.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_41.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_42.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_43.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_44.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_45.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_46.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_47.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_48.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_49.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_5.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_50.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_51.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_52.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_53.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_54.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_55.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_56.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_57.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_58.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_59.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_6.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_60.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_61.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_62.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_63.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_64.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_65.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_66.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_67.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_68.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_69.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_7.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_70.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_71.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_72.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_73.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_74.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_75.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_76.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_77.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_78.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_79.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_8.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_80.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_81.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_82.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_83.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_84.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_85.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_86.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_87.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_88.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_89.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_9.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_90.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_91.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_92.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_93.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_94.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_95.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_96.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_97.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_98.tif
#   inflating: Kaggle_Prepared/train/HS/Other_hyper_99.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_1.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_10.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_100.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_101.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_102.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_103.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_104.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_105.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_106.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_107.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_108.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_109.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_11.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_110.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_111.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_112.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_113.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_114.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_115.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_116.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_117.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_118.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_119.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_12.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_120.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_121.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_122.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_123.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_124.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_125.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_126.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_127.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_128.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_129.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_13.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_130.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_131.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_132.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_133.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_134.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_135.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_136.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_137.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_138.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_139.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_14.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_140.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_141.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_142.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_143.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_144.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_145.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_146.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_147.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_148.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_149.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_15.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_150.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_151.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_152.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_153.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_154.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_155.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_156.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_157.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_158.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_159.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_16.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_160.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_161.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_162.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_163.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_164.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_165.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_166.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_167.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_168.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_169.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_17.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_170.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_171.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_172.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_173.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_174.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_175.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_176.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_177.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_178.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_179.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_18.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_180.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_181.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_182.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_183.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_184.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_185.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_186.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_187.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_188.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_189.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_19.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_190.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_191.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_192.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_193.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_194.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_195.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_196.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_197.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_198.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_199.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_2.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_20.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_200.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_21.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_22.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_23.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_24.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_25.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_26.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_27.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_28.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_29.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_3.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_30.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_31.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_32.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_33.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_34.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_35.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_36.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_37.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_38.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_39.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_4.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_40.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_41.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_42.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_43.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_44.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_45.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_46.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_47.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_48.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_49.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_5.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_50.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_51.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_52.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_53.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_54.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_55.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_56.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_57.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_58.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_59.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_6.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_60.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_61.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_62.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_63.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_64.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_65.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_66.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_67.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_68.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_69.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_7.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_70.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_71.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_72.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_73.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_74.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_75.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_76.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_77.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_78.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_79.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_8.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_80.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_81.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_82.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_83.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_84.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_85.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_86.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_87.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_88.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_89.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_9.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_90.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_91.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_92.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_93.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_94.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_95.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_96.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_97.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_98.tif
#   inflating: Kaggle_Prepared/train/HS/Rust_hyper_99.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_1.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_10.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_100.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_101.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_102.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_103.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_104.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_105.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_106.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_107.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_108.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_109.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_11.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_110.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_111.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_112.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_113.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_114.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_115.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_116.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_117.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_118.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_119.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_12.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_120.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_121.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_122.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_123.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_124.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_125.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_126.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_127.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_128.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_129.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_13.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_130.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_131.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_132.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_133.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_134.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_135.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_136.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_137.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_138.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_139.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_14.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_140.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_141.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_142.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_143.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_144.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_145.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_146.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_147.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_148.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_149.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_15.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_150.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_151.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_152.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_153.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_154.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_155.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_156.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_157.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_158.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_159.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_16.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_160.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_161.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_162.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_163.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_164.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_165.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_166.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_167.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_168.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_169.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_17.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_170.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_171.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_172.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_173.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_174.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_175.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_176.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_177.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_178.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_179.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_18.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_180.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_181.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_182.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_183.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_184.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_185.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_186.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_187.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_188.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_189.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_19.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_190.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_191.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_192.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_193.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_194.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_195.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_196.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_197.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_198.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_199.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_2.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_20.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_200.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_21.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_22.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_23.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_24.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_25.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_26.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_27.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_28.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_29.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_3.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_30.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_31.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_32.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_33.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_34.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_35.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_36.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_37.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_38.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_39.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_4.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_40.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_41.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_42.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_43.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_44.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_45.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_46.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_47.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_48.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_49.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_5.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_50.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_51.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_52.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_53.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_54.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_55.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_56.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_57.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_58.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_59.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_6.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_60.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_61.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_62.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_63.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_64.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_65.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_66.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_67.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_68.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_69.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_7.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_70.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_71.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_72.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_73.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_74.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_75.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_76.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_77.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_78.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_79.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_8.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_80.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_81.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_82.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_83.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_84.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_85.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_86.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_87.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_88.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_89.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_9.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_90.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_91.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_92.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_93.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_94.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_95.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_96.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_97.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_98.tif
#   inflating: Kaggle_Prepared/train/MS/Health_hyper_99.tif
# ...
#   inflating: Kaggle_Prepared/val/RGB/val_1147aa81.png
#   inflating: Kaggle_Prepared/val/RGB/val_1157e423.png
#   inflating: Kaggle_Prepared/val/RGB/val_11fc3df9.png
#   inflating: Kaggle_Prepared/val/RGB/val_147643a2.png
#   inflating: Kaggle_Prepared/val/RGB/val_15e86c11.png
#   inflating: Kaggle_Prepared/val/RGB/val_16a0e917.png
#   inflating: Kaggle_Prepared/val/RGB/val_180483f1.png
#   inflating: Kaggle_Prepared/val/RGB/val_185c28ec.png
#   inflating: Kaggle_Prepared/val/RGB/val_19752faf.png
#   inflating: Kaggle_Prepared/val/RGB/val_19a91707.png
#   inflating: Kaggle_Prepared/val/RGB/val_1ad29634.png
#   inflating: Kaggle_Prepared/val/RGB/val_1d31c347.png
#   inflating: Kaggle_Prepared/val/RGB/val_1d63cdc8.png
#   inflating: Kaggle_Prepared/val/RGB/val_1dc03c71.png
#   inflating: Kaggle_Prepared/val/RGB/val_1df74c1b.png
#   inflating: Kaggle_Prepared/val/RGB/val_1e0be33a.png
#   inflating: Kaggle_Prepared/val/RGB/val_1ebd4873.png
#   inflating: Kaggle_Prepared/val/RGB/val_1fb27b70.png
#   inflating: Kaggle_Prepared/val/RGB/val_1ff2be67.png
#   inflating: Kaggle_Prepared/val/RGB/val_20087514.png
#   inflating: Kaggle_Prepared/val/RGB/val_20e42785.png
#   inflating: Kaggle_Prepared/val/RGB/val_222a4874.png
#   inflating: Kaggle_Prepared/val/RGB/val_22fc2410.png
#   inflating: Kaggle_Prepared/val/RGB/val_264d9a97.png
#   inflating: Kaggle_Prepared/val/RGB/val_274306a1.png
#   inflating: Kaggle_Prepared/val/RGB/val_2b215dcf.png
#   inflating: Kaggle_Prepared/val/RGB/val_2cd08e22.png
#   inflating: Kaggle_Prepared/val/RGB/val_2d21d0d1.png
#   inflating: Kaggle_Prepared/val/RGB/val_2ddd1bb4.png
#   inflating: Kaggle_Prepared/val/RGB/val_2e08eeff.png
#   inflating: Kaggle_Prepared/val/RGB/val_2e2cde42.png
#   inflating: Kaggle_Prepared/val/RGB/val_2e44c155.png
#   inflating: Kaggle_Prepared/val/RGB/val_2eb97425.png
#   inflating: Kaggle_Prepared/val/RGB/val_2f371eb8.png
#   inflating: Kaggle_Prepared/val/RGB/val_30107726.png
#   inflating: Kaggle_Prepared/val/RGB/val_30d17cde.png
#   inflating: Kaggle_Prepared/val/RGB/val_31a6a18d.png
#   inflating: Kaggle_Prepared/val/RGB/val_357a9567.png
#   inflating: Kaggle_Prepared/val/RGB/val_35e2faef.png
#   inflating: Kaggle_Prepared/val/RGB/val_3695f734.png
#   inflating: Kaggle_Prepared/val/RGB/val_36c18096.png
#   inflating: Kaggle_Prepared/val/RGB/val_36e957bb.png
#   inflating: Kaggle_Prepared/val/RGB/val_3766bcf8.png
#   inflating: Kaggle_Prepared/val/RGB/val_37c8cc6c.png
#   inflating: Kaggle_Prepared/val/RGB/val_3a09250f.png
#   inflating: Kaggle_Prepared/val/RGB/val_3a61aa62.png
#   inflating: Kaggle_Prepared/val/RGB/val_3a67986e.png
#   inflating: Kaggle_Prepared/val/RGB/val_3a6a53b3.png
#   inflating: Kaggle_Prepared/val/RGB/val_3f6a4de8.png
#   inflating: Kaggle_Prepared/val/RGB/val_3f8685fe.png
#   inflating: Kaggle_Prepared/val/RGB/val_40d88f13.png
#   inflating: Kaggle_Prepared/val/RGB/val_41059371.png
#   inflating: Kaggle_Prepared/val/RGB/val_41a41062.png
#   inflating: Kaggle_Prepared/val/RGB/val_44391beb.png
#   inflating: Kaggle_Prepared/val/RGB/val_44f91bba.png
#   inflating: Kaggle_Prepared/val/RGB/val_45bfdb87.png
#   inflating: Kaggle_Prepared/val/RGB/val_4606d55e.png
#   inflating: Kaggle_Prepared/val/RGB/val_46511c23.png
#   inflating: Kaggle_Prepared/val/RGB/val_47168ee2.png
#   inflating: Kaggle_Prepared/val/RGB/val_47de91ce.png
#   inflating: Kaggle_Prepared/val/RGB/val_483d4c50.png
#   inflating: Kaggle_Prepared/val/RGB/val_49c1e309.png
#   inflating: Kaggle_Prepared/val/RGB/val_4b458633.png
#   inflating: Kaggle_Prepared/val/RGB/val_4db30a2c.png
#   inflating: Kaggle_Prepared/val/RGB/val_4de40fdf.png
#   inflating: Kaggle_Prepared/val/RGB/val_500c6a92.png
#   inflating: Kaggle_Prepared/val/RGB/val_53270b0f.png
#   inflating: Kaggle_Prepared/val/RGB/val_53648d10.png
#   inflating: Kaggle_Prepared/val/RGB/val_5372f1e7.png
#   inflating: Kaggle_Prepared/val/RGB/val_57bc995b.png
#   inflating: Kaggle_Prepared/val/RGB/val_58df2f68.png
#   inflating: Kaggle_Prepared/val/RGB/val_5a361ff8.png
#   inflating: Kaggle_Prepared/val/RGB/val_5adcdc2e.png
#   inflating: Kaggle_Prepared/val/RGB/val_5afc79c8.png
#   inflating: Kaggle_Prepared/val/RGB/val_5bd2522f.png
#   inflating: Kaggle_Prepared/val/RGB/val_5ea8e3ba.png
#   inflating: Kaggle_Prepared/val/RGB/val_5fab1376.png
#   inflating: Kaggle_Prepared/val/RGB/val_5fc55ef7.png
#   inflating: Kaggle_Prepared/val/RGB/val_604b91f0.png
#   inflating: Kaggle_Prepared/val/RGB/val_6136f820.png
#   inflating: Kaggle_Prepared/val/RGB/val_62db1e6f.png
#   inflating: Kaggle_Prepared/val/RGB/val_6338d9e6.png
#   inflating: Kaggle_Prepared/val/RGB/val_640be560.png
#   inflating: Kaggle_Prepared/val/RGB/val_65f656ec.png
#   inflating: Kaggle_Prepared/val/RGB/val_66f797e1.png
#   inflating: Kaggle_Prepared/val/RGB/val_672cd515.png
#   inflating: Kaggle_Prepared/val/RGB/val_676f21c4.png
#   inflating: Kaggle_Prepared/val/RGB/val_67af5dc8.png
#   inflating: Kaggle_Prepared/val/RGB/val_67c80815.png
#   inflating: Kaggle_Prepared/val/RGB/val_688d8eae.png
#   inflating: Kaggle_Prepared/val/RGB/val_68aa3069.png
#   inflating: Kaggle_Prepared/val/RGB/val_68f339c4.png
#   inflating: Kaggle_Prepared/val/RGB/val_6904db6a.png
#   inflating: Kaggle_Prepared/val/RGB/val_69f91160.png
#   inflating: Kaggle_Prepared/val/RGB/val_6a351fa5.png
#   inflating: Kaggle_Prepared/val/RGB/val_6aa2e3d0.png
#   inflating: Kaggle_Prepared/val/RGB/val_6b1a72fd.png
#   inflating: Kaggle_Prepared/val/RGB/val_6b6509fd.png
#   inflating: Kaggle_Prepared/val/RGB/val_6c142943.png
#   inflating: Kaggle_Prepared/val/RGB/val_6c1c4dc6.png
#   inflating: Kaggle_Prepared/val/RGB/val_6cef0158.png
#   inflating: Kaggle_Prepared/val/RGB/val_6dff8663.png
#   inflating: Kaggle_Prepared/val/RGB/val_7127f7c8.png
#   inflating: Kaggle_Prepared/val/RGB/val_71d2759c.png
#   inflating: Kaggle_Prepared/val/RGB/val_7395d111.png
#   inflating: Kaggle_Prepared/val/RGB/val_743c8012.png
#   inflating: Kaggle_Prepared/val/RGB/val_759a72ba.png
#   inflating: Kaggle_Prepared/val/RGB/val_75bd9d09.png
#   inflating: Kaggle_Prepared/val/RGB/val_76b734ac.png
#   inflating: Kaggle_Prepared/val/RGB/val_7b2af9c3.png
#   inflating: Kaggle_Prepared/val/RGB/val_7ce5ee63.png
#   inflating: Kaggle_Prepared/val/RGB/val_7ce60a77.png
#   inflating: Kaggle_Prepared/val/RGB/val_7de8df5a.png
#   inflating: Kaggle_Prepared/val/RGB/val_7f2b8400.png
#   inflating: Kaggle_Prepared/val/RGB/val_7f561b5d.png
#   inflating: Kaggle_Prepared/val/RGB/val_80e3f278.png
#   inflating: Kaggle_Prepared/val/RGB/val_81fa3c3e.png
#   inflating: Kaggle_Prepared/val/RGB/val_8397daf7.png
#   inflating: Kaggle_Prepared/val/RGB/val_848712e4.png
#   inflating: Kaggle_Prepared/val/RGB/val_84995ce8.png
#   inflating: Kaggle_Prepared/val/RGB/val_84be8027.png
#   inflating: Kaggle_Prepared/val/RGB/val_84cbd32d.png
#   inflating: Kaggle_Prepared/val/RGB/val_857f4536.png
#   inflating: Kaggle_Prepared/val/RGB/val_866b354c.png
#   inflating: Kaggle_Prepared/val/RGB/val_86739c82.png
#   inflating: Kaggle_Prepared/val/RGB/val_8737d33f.png
#   inflating: Kaggle_Prepared/val/RGB/val_8889cbed.png
#   inflating: Kaggle_Prepared/val/RGB/val_89122c1e.png
#   inflating: Kaggle_Prepared/val/RGB/val_89699d76.png
#   inflating: Kaggle_Prepared/val/RGB/val_8b8362e5.png
#   inflating: Kaggle_Prepared/val/RGB/val_8d7acaae.png
#   inflating: Kaggle_Prepared/val/RGB/val_8e35e5d5.png
#   inflating: Kaggle_Prepared/val/RGB/val_8e9e3f20.png
#   inflating: Kaggle_Prepared/val/RGB/val_8ebe83d8.png
#   inflating: Kaggle_Prepared/val/RGB/val_8efcaee7.png
#   inflating: Kaggle_Prepared/val/RGB/val_8fa76dd5.png
#   inflating: Kaggle_Prepared/val/RGB/val_9265fd4f.png
#   inflating: Kaggle_Prepared/val/RGB/val_94d72cf9.png
#   inflating: Kaggle_Prepared/val/RGB/val_94f98751.png
#   inflating: Kaggle_Prepared/val/RGB/val_9526c1c0.png
#   inflating: Kaggle_Prepared/val/RGB/val_95644e7a.png
#   inflating: Kaggle_Prepared/val/RGB/val_986dc7b5.png
#   inflating: Kaggle_Prepared/val/RGB/val_98b71660.png
#   inflating: Kaggle_Prepared/val/RGB/val_98efde52.png
#   inflating: Kaggle_Prepared/val/RGB/val_992d823d.png
#   inflating: Kaggle_Prepared/val/RGB/val_99c4d66f.png
#   inflating: Kaggle_Prepared/val/RGB/val_9a4bf1b3.png
#   inflating: Kaggle_Prepared/val/RGB/val_9c32d2de.png
#   inflating: Kaggle_Prepared/val/RGB/val_9c86f666.png
#   inflating: Kaggle_Prepared/val/RGB/val_9dc465fd.png
#   inflating: Kaggle_Prepared/val/RGB/val_9eb4f156.png
#   inflating: Kaggle_Prepared/val/RGB/val_9f95beac.png
#   inflating: Kaggle_Prepared/val/RGB/val_9fa559c8.png
#   inflating: Kaggle_Prepared/val/RGB/val_9fdb8129.png
#   inflating: Kaggle_Prepared/val/RGB/val_a236c630.png
#   inflating: Kaggle_Prepared/val/RGB/val_a35051b0.png
#   inflating: Kaggle_Prepared/val/RGB/val_a40dab77.png
#   inflating: Kaggle_Prepared/val/RGB/val_a4353142.png
#   inflating: Kaggle_Prepared/val/RGB/val_a51a4db3.png
#   inflating: Kaggle_Prepared/val/RGB/val_a54fa0cc.png
#   inflating: Kaggle_Prepared/val/RGB/val_a72d6dc0.png
#   inflating: Kaggle_Prepared/val/RGB/val_a7aa073c.png
#   inflating: Kaggle_Prepared/val/RGB/val_a7edf8d2.png
#   inflating: Kaggle_Prepared/val/RGB/val_a82aa0fa.png
#   inflating: Kaggle_Prepared/val/RGB/val_a97e31ee.png
#   inflating: Kaggle_Prepared/val/RGB/val_a999cac9.png
#   inflating: Kaggle_Prepared/val/RGB/val_a9d4b100.png
#   inflating: Kaggle_Prepared/val/RGB/val_abefe139.png
#   inflating: Kaggle_Prepared/val/RGB/val_ac83f12c.png
#   inflating: Kaggle_Prepared/val/RGB/val_add7169c.png
#   inflating: Kaggle_Prepared/val/RGB/val_af4bea21.png
#   inflating: Kaggle_Prepared/val/RGB/val_b0ab7f6a.png
#   inflating: Kaggle_Prepared/val/RGB/val_b1a321b7.png
#   inflating: Kaggle_Prepared/val/RGB/val_b2711ce6.png
#   inflating: Kaggle_Prepared/val/RGB/val_b34517b7.png
#   inflating: Kaggle_Prepared/val/RGB/val_b378be0b.png
#   inflating: Kaggle_Prepared/val/RGB/val_b394d497.png
#   inflating: Kaggle_Prepared/val/RGB/val_b4efdc58.png
#   inflating: Kaggle_Prepared/val/RGB/val_b523bc4d.png
#   inflating: Kaggle_Prepared/val/RGB/val_b52c485a.png
#   inflating: Kaggle_Prepared/val/RGB/val_b5b4fbcc.png
#   inflating: Kaggle_Prepared/val/RGB/val_b691522f.png
#   inflating: Kaggle_Prepared/val/RGB/val_b6c9d3d7.png
#   inflating: Kaggle_Prepared/val/RGB/val_b6feb0b5.png
#   inflating: Kaggle_Prepared/val/RGB/val_b77cbc86.png
#   inflating: Kaggle_Prepared/val/RGB/val_b7a1d2f1.png
#   inflating: Kaggle_Prepared/val/RGB/val_b81dbdfe.png
#   inflating: Kaggle_Prepared/val/RGB/val_b822b957.png
#   inflating: Kaggle_Prepared/val/RGB/val_b826d518.png
#   inflating: Kaggle_Prepared/val/RGB/val_b8b2cbc2.png
#   inflating: Kaggle_Prepared/val/RGB/val_b8d1e576.png
#   inflating: Kaggle_Prepared/val/RGB/val_bb78e8a7.png
#   inflating: Kaggle_Prepared/val/RGB/val_bbcdad89.png
#   inflating: Kaggle_Prepared/val/RGB/val_bbcf9fe5.png
#   inflating: Kaggle_Prepared/val/RGB/val_bbda6767.png
#   inflating: Kaggle_Prepared/val/RGB/val_bc1bab51.png
#   inflating: Kaggle_Prepared/val/RGB/val_bc388562.png
#   inflating: Kaggle_Prepared/val/RGB/val_bdbe7456.png
#   inflating: Kaggle_Prepared/val/RGB/val_bff0763d.png
#   inflating: Kaggle_Prepared/val/RGB/val_c388ecb9.png
#   inflating: Kaggle_Prepared/val/RGB/val_c4158ad0.png
#   inflating: Kaggle_Prepared/val/RGB/val_c4598f3c.png
#   inflating: Kaggle_Prepared/val/RGB/val_c54d2bfa.png
#   inflating: Kaggle_Prepared/val/RGB/val_c55250e7.png
#   inflating: Kaggle_Prepared/val/RGB/val_c8608ba7.png
#   inflating: Kaggle_Prepared/val/RGB/val_c8791719.png
#   inflating: Kaggle_Prepared/val/RGB/val_c8c93eaa.png
#   inflating: Kaggle_Prepared/val/RGB/val_c8f4b814.png
#   inflating: Kaggle_Prepared/val/RGB/val_c956c61d.png
#   inflating: Kaggle_Prepared/val/RGB/val_c988b239.png
#   inflating: Kaggle_Prepared/val/RGB/val_c9cef268.png
#   inflating: Kaggle_Prepared/val/RGB/val_cc138b03.png
#   inflating: Kaggle_Prepared/val/RGB/val_cc2ca03e.png
#   inflating: Kaggle_Prepared/val/RGB/val_ccb2491e.png
#   inflating: Kaggle_Prepared/val/RGB/val_cd11b52b.png
#   inflating: Kaggle_Prepared/val/RGB/val_ceaa5449.png
#   inflating: Kaggle_Prepared/val/RGB/val_d113c25f.png
#   inflating: Kaggle_Prepared/val/RGB/val_d1d81b47.png
#   inflating: Kaggle_Prepared/val/RGB/val_d3421d43.png
#   inflating: Kaggle_Prepared/val/RGB/val_d3ccc922.png
#   inflating: Kaggle_Prepared/val/RGB/val_d4984b6c.png
#   inflating: Kaggle_Prepared/val/RGB/val_d4bdd2fb.png
#   inflating: Kaggle_Prepared/val/RGB/val_d55d6e58.png
#   inflating: Kaggle_Prepared/val/RGB/val_d6d67cf3.png
#   inflating: Kaggle_Prepared/val/RGB/val_d6d8faa6.png
#   inflating: Kaggle_Prepared/val/RGB/val_d768878f.png
#   inflating: Kaggle_Prepared/val/RGB/val_d7b2a318.png
#   inflating: Kaggle_Prepared/val/RGB/val_d7fc83cd.png
#   inflating: Kaggle_Prepared/val/RGB/val_d88258eb.png
#   inflating: Kaggle_Prepared/val/RGB/val_da53be12.png
#   inflating: Kaggle_Prepared/val/RGB/val_da9148e1.png
#   inflating: Kaggle_Prepared/val/RGB/val_daa666bc.png
#   inflating: Kaggle_Prepared/val/RGB/val_dad4681b.png
#   inflating: Kaggle_Prepared/val/RGB/val_dc0b8d70.png
#   inflating: Kaggle_Prepared/val/RGB/val_dc5d857c.png
#   inflating: Kaggle_Prepared/val/RGB/val_de1b5896.png
#   inflating: Kaggle_Prepared/val/RGB/val_de6bcd4e.png
#   inflating: Kaggle_Prepared/val/RGB/val_dea7b29d.png
#   inflating: Kaggle_Prepared/val/RGB/val_deda51bb.png
#   inflating: Kaggle_Prepared/val/RGB/val_df4837c1.png
#   inflating: Kaggle_Prepared/val/RGB/val_e0479a61.png
#   inflating: Kaggle_Prepared/val/RGB/val_e1629b46.png
#   inflating: Kaggle_Prepared/val/RGB/val_e2845912.png
#   inflating: Kaggle_Prepared/val/RGB/val_e2969714.png
#   inflating: Kaggle_Prepared/val/RGB/val_e4605d0d.png
#   inflating: Kaggle_Prepared/val/RGB/val_e5abd239.png
#   inflating: Kaggle_Prepared/val/RGB/val_e804bb69.png
#   inflating: Kaggle_Prepared/val/RGB/val_e8238864.png
#   inflating: Kaggle_Prepared/val/RGB/val_e88c83bf.png
#   inflating: Kaggle_Prepared/val/RGB/val_e90aa9a8.png
#   inflating: Kaggle_Prepared/val/RGB/val_e9a3cc79.png
#   inflating: Kaggle_Prepared/val/RGB/val_e9ce960f.png
#   inflating: Kaggle_Prepared/val/RGB/val_e9e8ce23.png
#   inflating: Kaggle_Prepared/val/RGB/val_ebd5e85f.png
#   inflating: Kaggle_Prepared/val/RGB/val_ee0dd53f.png
#   inflating: Kaggle_Prepared/val/RGB/val_ee803b15.png
#   inflating: Kaggle_Prepared/val/RGB/val_efdc49ea.png
#   inflating: Kaggle_Prepared/val/RGB/val_efeb1a45.png
#   inflating: Kaggle_Prepared/val/RGB/val_f032e5be.png
#   inflating: Kaggle_Prepared/val/RGB/val_f049cacb.png
#   inflating: Kaggle_Prepared/val/RGB/val_f0a30df9.png
#   inflating: Kaggle_Prepared/val/RGB/val_f0d99865.png
#   inflating: Kaggle_Prepared/val/RGB/val_f19e25ce.png
#   inflating: Kaggle_Prepared/val/RGB/val_f1a4afff.png
#   inflating: Kaggle_Prepared/val/RGB/val_f1fed156.png
#   inflating: Kaggle_Prepared/val/RGB/val_f25c0c10.png
#   inflating: Kaggle_Prepared/val/RGB/val_f2b503c3.png
#   inflating: Kaggle_Prepared/val/RGB/val_f424ae34.png
#   inflating: Kaggle_Prepared/val/RGB/val_f44c5f6a.png
#   inflating: Kaggle_Prepared/val/RGB/val_f4ad06bb.png
#   inflating: Kaggle_Prepared/val/RGB/val_f5cf987f.png
#   inflating: Kaggle_Prepared/val/RGB/val_f618e232.png
#   inflating: Kaggle_Prepared/val/RGB/val_f63bd6e1.png
#   inflating: Kaggle_Prepared/val/RGB/val_f6466225.png
#   inflating: Kaggle_Prepared/val/RGB/val_f67249e6.png
#   inflating: Kaggle_Prepared/val/RGB/val_f720cb3d.png
#   inflating: Kaggle_Prepared/val/RGB/val_f73b79e5.png
#   inflating: Kaggle_Prepared/val/RGB/val_f7ccfa2c.png
#   inflating: Kaggle_Prepared/val/RGB/val_fa308719.png
#   inflating: Kaggle_Prepared/val/RGB/val_fa49e86d.png
#   inflating: Kaggle_Prepared/val/RGB/val_fa892201.png
#   inflating: Kaggle_Prepared/val/RGB/val_fabc42be.png
#   inflating: Kaggle_Prepared/val/RGB/val_fac15190.png
#   inflating: Kaggle_Prepared/val/RGB/val_fde50c68.png
#   inflating: Kaggle_Prepared/val/RGB/val_ffbaf88b.png

# %%
import torch
import torch.nn as nn
import timm  # مكتبة الموديلات الجاهزة

def create_baseline_model():

    model = timm.create_model('resnet50', pretrained=True, num_classes=3)
    return model

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = create_baseline_model().to(device)

print(f" model ready on : {device}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/102M [00:00<?, ?B/s]
# الموديل جاهز وشغال على: cuda

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
import time

def train_model(model, train_loader, criterion, optimizer, num_epochs=5):
    model.train()
    for epoch in range(num_epochs):
        running_loss = 0.0
        correct = 0
        total = 0
        start_time = time.time()

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)

            optimizer.zero_grad()

            outputs = model(images)
            loss = criterion(outputs, labels)

            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

        epoch_loss = running_loss / len(train_loader)
        epoch_acc = 100. * correct / total
        end_time = time.time()

        print(f'Epoch [{epoch+1}/{num_epochs}] - Loss: {epoch_loss:.4f}, Acc: {epoch_acc:.2f}% - Time: {end_time - start_time:.2f}s')

# %%
import pandas as pd
import os
import re

# Path where the Kaggle data is unzipped
kaggle_prepared_dir = '/content/Kaggle_Prepared'

csv_paths = !find {kaggle_prepared_dir} -maxdepth 2 -name "*.csv"

if not csv_paths:
    print("No CSV files found. Generating 'train_labels.csv' from training image filenames.")

    generated_data = []
    train_base_path = os.path.join(kaggle_prepared_dir, 'train')

    for modality in ['HS', 'MS', 'RGB']:
        modality_path = os.path.join(train_base_path, modality)
        if os.path.isdir(modality_path):
            for filename in os.listdir(modality_path):
                file_id = os.path.splitext(filename)[0]
                match = re.match(r'^(Health|Rust|Other)_.*', file_id)
                if match:
                    label = match.group(1)
                    generated_data.append({'file_name': file_id, 'label': label, 'split': 'train', 'modality': modality})

    if generated_data:
        labels_df = pd.DataFrame(generated_data)
        output_csv_path = os.path.join(kaggle_prepared_dir, 'train_labels.csv')
        labels_df.to_csv(output_csv_path, index=False)
        csv_path = output_csv_path #
        print(f"Successfully generated '{os.path.basename(csv_path)}' at {os.path.dirname(csv_path)}")
    else:

        raise FileNotFoundError("No CSV files found and unable to generate a 'train_labels.csv' from image filenames with discernible labels.")
else:
    csv_path = csv_paths[0]

print(f"تم إيجاد الملف في: {csv_path}")

# قراءة الملف
df = pd.read_csv(csv_path)
print(f"number of photos: {len(df)}")
print(df.head())
print("Classes")
print(df['label'].value_counts())
# Out:
# No CSV files found. Generating 'train_labels.csv' from training image filenames.
# Successfully generated 'train_labels.csv' at /content/Kaggle_Prepared
# تم إيجاد الملف في: /content/Kaggle_Prepared/train_labels.csv
# number of photos: 1800
#           file_name   label  split modality
# 0     Rust_hyper_37    Rust  train       HS
# 1   Other_hyper_169   Other  train       HS
# 2  Health_hyper_153  Health  train       HS
# 3   Other_hyper_109   Other  train       HS
# 4  Health_hyper_189  Health  train       HS
# Classes
# label
# Rust      600
# Other     600
# Health    600
# Name: count, dtype: int64

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import cv2
import os

class WheatDataset(Dataset):
    def __init__(self, df, base_dir, transform=None):
        self.df = df
        self.base_dir = base_dir
        self.transform = transform
        self.label_map = {"Health": 0, "Rust": 1, "Other": 2}

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]

        img_path = os.path.join(self.base_dir, row['split'], 'RGB', row['file_name'] + '.png')

        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

        image = torch.from_numpy(image).permute(2, 0, 1).float() / 255.0
        label = torch.tensor(self.label_map[row['label']])

        return image, label

train_ds = WheatDataset(df, '/content/Kaggle_Prepared')
train_loader = DataLoader(train_ds, batch_size=16, shuffle=True)

# %%
import timm
import torch.nn as nn

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = timm.create_model('resnet50', pretrained=True, num_classes=3)
model = model.to(device)


criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)

print(f" model ready for trainning on  : {device}")
# Out:
# الموديل جاهز للتدريب على: cuda

# %%
num_epochs = 10

print("trainning start")
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()

    acc = 100. * correct / total
    print(f'Epoch [{epoch+1}/{num_epochs}] - Loss: {running_loss/len(train_loader):.4f} - Acc: {acc:.2f}%')
# Out:
# 🚀 بدأ التدريب...
# Epoch [1/10] - Loss: 1.0840 - Acc: 41.56%
# Epoch [2/10] - Loss: 1.0148 - Acc: 56.72%
# Epoch [3/10] - Loss: 0.9010 - Acc: 64.33%
# Epoch [4/10] - Loss: 0.7718 - Acc: 68.67%
# Epoch [5/10] - Loss: 0.6450 - Acc: 74.56%
# Epoch [6/10] - Loss: 0.5259 - Acc: 80.17%
# Epoch [7/10] - Loss: 0.4189 - Acc: 85.22%
# Epoch [8/10] - Loss: 0.3276 - Acc: 89.11%
# Epoch [9/10] - Loss: 0.2560 - Acc: 92.39%
# Epoch [10/10] - Loss: 0.2181 - Acc: 92.39%
# ✅ خلصنا أول Baseline!

# %%
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader

train_df, val_df = train_test_split(df, test_size=0.2, stratify=df['label'], random_state=42)

train_ds = WheatDataset(train_df, '/content/Kaggle_Prepared')
val_ds = WheatDataset(val_df, '/content/Kaggle_Prepared')

train_loader = DataLoader(train_ds, batch_size=16, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=16, shuffle=False)

print("val images number" ,len(val_df))
# Out:
# تم تجهيز الـ val_loader بنجاح! عدد صور التحقق: 360

# %%
from sklearn.metrics import classification_report
import numpy as np

model.eval()
all_preds = []
all_labels = []

with torch.no_grad():
    for images, labels in val_loader:
        images = images.to(device)
        outputs = model(images)
        _, preds = torch.max(outputs, 1)
        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(labels.numpy())

print(classification_report(all_labels, all_preds, target_names=["Health", "Rust", "Other"]))
# Out:
#               precision    recall  f1-score   support
#
#       Health       0.95      0.94      0.95       120
#         Rust       0.96      1.00      0.98       120
#        Other       0.96      0.93      0.94       120
#
#     accuracy                           0.96       360
#    macro avg       0.96      0.96      0.96       360
# weighted avg       0.96      0.96      0.96       360

# %%
import tifffile as tiff
import numpy as np
import torch.nn.functional as F

class MultimodalWheatDataset(Dataset):
    def __init__(self, df, base_dir, transform=None):
        self.df = df
        self.base_dir = base_dir
        self.label_map = {"Health": 0, "Rust": 1, "Other": 2}
        self.target_hs_channels = 126

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]

        rgb_path = os.path.join(self.base_dir, row['split'], 'RGB', row['file_name'] + '.png')
        rgb_img = cv2.imread(rgb_path)
        rgb_img = cv2.cvtColor(rgb_img, cv2.COLOR_BGR2RGB)
        rgb_tensor = torch.from_numpy(rgb_img).permute(2, 0, 1).float() / 255.0

        hs_path = os.path.join(self.base_dir, row['split'], 'HS', row['file_name'] + '.tif')
        hs_img = tiff.imread(hs_path)

        if hs_img.ndim == 2:
            hs_img = np.expand_dims(hs_img, axis=-1)

        hs_tensor = torch.from_numpy(hs_img).permute(2, 0, 1).float()

        current_hs_channels = hs_tensor.shape[0]
        if current_hs_channels < self.target_hs_channels:
            padding_needed = self.target_hs_channels - current_hs_channels
            hs_tensor = F.pad(hs_tensor, (0, 0, 0, 0, 0, padding_needed), 'constant', 0)
        elif current_hs_channels > self.target_hs_channels:
            hs_tensor = hs_tensor[:self.target_hs_channels, :, :]

        label = torch.tensor(self.label_map[row['label']])

        return rgb_tensor, hs_tensor, label

# %%
import torch.nn as nn
import timm

class MultimodalFusionModel(nn.Module):
    def __init__(self, hs_channels, num_classes=3):
        super(MultimodalFusionModel, self).__init__()

        self.rgb_branch = timm.create_model('resnet50', pretrained=True, num_classes=0) # بدون آخر طبقة

        self.hs_branch = nn.Sequential(
            nn.Conv2d(hs_channels, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Flatten()
        )

        self.classifier = nn.Linear(2048 + 64, num_classes)

    def forward(self, rgb, hs):
        rgb_features = self.rgb_branch(rgb)
        hs_features = self.hs_branch(hs)

        combined_features = torch.cat((rgb_features, hs_features), dim=1)

        output = self.classifier(combined_features)
        return output

model_innovative = MultimodalFusionModel(hs_channels=126).to(device)
optimizer = torch.optim.Adam(model_innovative.parameters(), lr=0.0001)
# Out:
# ✅ تم بناء موديل الابتكار بنجاح!

# %%
sample_dataset = MultimodalWheatDataset(df, '/content/Kaggle_Prepared')
rgb_sample, hs_sample, label_sample = sample_dataset[0]
print(f"RGB Image Shape: {rgb_sample.shape}")
print(f"HS Image Shape: {hs_sample.shape}")
# Out:
# RGB Image Shape: torch.Size([3, 64, 64])
# HS Image Shape: torch.Size([126, 32, 32])

# %%
import torch.nn as nn
import timm

class MultimodalFusionModel(nn.Module):
    def __init__(self, num_classes=3):
        super(MultimodalFusionModel, self).__init__()

        self.rgb_branch = timm.create_model('resnet50', pretrained=True, num_classes=0)

        self.hs_branch = nn.Sequential(
            nn.Conv2d(126, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Flatten()
        )

        self.classifier = nn.Linear(2048 + 64, num_classes)

    def forward(self, rgb, hs):
        rgb_feat = self.rgb_branch(rgb)
        hs_feat = self.hs_branch(hs)

        combined = torch.cat((rgb_feat, hs_feat), dim=1)
        return self.classifier(combined)


model_innovative = MultimodalFusionModel().to(device)
optimizer = torch.optim.Adam(model_innovative.parameters(), lr=0.0001)
criterion = nn.CrossEntropyLoss()

# %%
def train_multimodal(model, loader, epochs=10):
    model.train()
    for epoch in range(epochs):
        correct = 0
        total = 0
        for rgb, hs, labels in loader:
            rgb, hs, labels = rgb.to(device), hs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(rgb, hs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

        print(f"Epoch [{epoch+1}/{epochs}] - Accuracy: {100.*correct/total:.2f}%")


train_loader_multi = DataLoader(MultimodalWheatDataset(train_df, '/content/Kaggle_Prepared'), batch_size=16, shuffle=True)
train_multimodal(model_innovative, train_loader_multi)
# Out:
# Epoch [1/10] - Accuracy: 53.68%
# Epoch [2/10] - Accuracy: 63.61%
# Epoch [3/10] - Accuracy: 66.04%
# Epoch [4/10] - Accuracy: 68.96%
# Epoch [5/10] - Accuracy: 74.51%
# Epoch [6/10] - Accuracy: 76.11%
# Epoch [7/10] - Accuracy: 79.93%
# Epoch [8/10] - Accuracy: 86.11%
# Epoch [9/10] - Accuracy: 87.78%
# Epoch [10/10] - Accuracy: 91.32%

# %%
from sklearn.metrics import classification_report
from torch.utils.data import DataLoader

final_val_ds = MultimodalWheatDataset(val_df, '/content/Kaggle_Prepared')
val_loader = DataLoader(final_val_ds, batch_size=16, shuffle=False)

model_innovative.eval()
y_true, y_pred = [], []

with torch.no_grad():
    for rgb, hs, labels in val_loader:
        rgb, hs = rgb.to(device), hs.to(device)
        outputs = model_innovative(rgb, hs)
        _, predicted = torch.max(outputs, 1)
        y_true.extend(labels.numpy())
        y_pred.extend(predicted.cpu().numpy())

print(classification_report(y_true, y_pred, target_names=["Health", "Rust", "Other"]))
# Out:
#               precision    recall  f1-score   support
#
#       Health       0.90      0.90      0.90       120
#         Rust       0.97      0.96      0.97       120
#        Other       0.90      0.92      0.91       120
#
#     accuracy                           0.93       360
#    macro avg       0.93      0.92      0.93       360
# weighted avg       0.93      0.93      0.93       360

# %%
import tifffile as tiff
import numpy as np
import torch.nn.functional as F # Import for padding

class TripleModalityDataset(Dataset):
    def __init__(self, df, base_dir):
        self.df = df
        self.base_dir = base_dir
        self.label_map = {"Health": 0, "Rust": 1, "Other": 2}
        self.target_hs_channels = 126 # Define a target for HS channels, matching your model

    def __len__(self): return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        split = row['split']
        name = row['file_name']

        # 1. RGB (3 channels)
        rgb_path = os.path.join(self.base_dir, split, 'RGB', name + '.png')
        rgb = cv2.imread(rgb_path)
        rgb = torch.from_numpy(cv2.cvtColor(rgb, cv2.COLOR_BGR2RGB)).permute(2, 0, 1).float() / 255.0

        # 2. MS (5 channels)
        ms_path = os.path.join(self.base_dir, split, 'MS', name + '.tif')
        ms = tiff.imread(ms_path)
        # Ensure ms is 3D (Height, Width, Channels) for consistency before permuting
        if ms.ndim == 2:
            ms = np.expand_dims(ms, axis=-1)
        ms = torch.from_numpy(ms).permute(2, 0, 1).float()

        # 3. HS (126 channels)
        hs_path = os.path.join(self.base_dir, split, 'HS', name + '.tif')
        hs = tiff.imread(hs_path)
        if hs.ndim == 2:
            hs = np.expand_dims(hs, axis=-1)
        hs = torch.from_numpy(hs).permute(2, 0, 1).float()

        # Handle varying HS channel counts
        current_hs_channels = hs.shape[0]
        if current_hs_channels < self.target_hs_channels:
            # Pad with zeros along the channel dimension
            padding_needed = self.target_hs_channels - current_hs_channels
            # pad = (pad_left_width, pad_right_width, pad_left_height, pad_right_height, pad_left_channels, pad_right_channels)
            hs = F.pad(hs, (0, 0, 0, 0, 0, padding_needed), 'constant', 0)
        elif current_hs_channels > self.target_hs_channels:
            # Crop if there are more channels than expected
            hs = hs[:self.target_hs_channels, :, :]

        return rgb, ms, hs, torch.tensor(self.label_map[row['label']])

# %%
class TripleFusionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.rgb_branch = timm.create_model('resnet50', pretrained=True, num_classes=0)

        self.ms_branch = nn.Sequential(
            nn.Conv2d(5, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Flatten()
        )

        self.hs_branch = nn.Sequential(
            nn.Conv2d(126, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.AdaptiveAvgPool2d((1, 1)),
            nn.Flatten()
        )


        self.classifier = nn.Linear(2048 + 32 + 64, 3)

    def forward(self, rgb, ms, hs):
        f_rgb = self.rgb_branch(rgb)
        f_ms = self.ms_branch(ms)
        f_hs = self.hs_branch(hs)

        combined = torch.cat((f_rgb, f_ms, f_hs), dim=1)
        return self.classifier(combined)

model_final = TripleFusionModel().to(device)
optimizer = torch.optim.Adam(model_final.parameters(), lr=0.0001)

# %%
def train_triple_fusion(model, loader, epochs=10):
    model.train()
    print("Train triple fusion  (RGB + MS + HS)...")
    for epoch in range(epochs):
        running_loss = 0.0
        correct = 0
        total = 0

        for rgb, ms, hs, labels in loader:
            rgb, ms, hs, labels = rgb.to(device), ms.to(device), hs.to(device), labels.to(device)

            optimizer.zero_grad()

            outputs = model(rgb, ms, hs)
            loss = criterion(outputs, labels)

            loss.backward()
            optimizer.step()

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

        epoch_acc = 100. * correct / total
        print(f"Epoch [{epoch+1}/{epochs}] - Loss: {running_loss/len(loader):.4f} - Accuracy: {epoch_acc:.2f}%")


final_train_ds = TripleModalityDataset(train_df, '/content/Kaggle_Prepared')
final_train_loader = DataLoader(final_train_ds, batch_size=16, shuffle=True)

train_triple_fusion(model_final, final_train_loader, epochs=20)
# Out:
# Train triple fusion  (RGB + MS + HS)...
# Epoch [1/20] - Loss: 2.2409 - Accuracy: 68.96%
# Epoch [2/20] - Loss: 1.5186 - Accuracy: 74.10%
# Epoch [3/20] - Loss: 1.3921 - Accuracy: 73.75%
# Epoch [4/20] - Loss: 1.1912 - Accuracy: 77.92%
# Epoch [5/20] - Loss: 1.5365 - Accuracy: 77.15%
# Epoch [6/20] - Loss: 1.1330 - Accuracy: 80.21%
# Epoch [7/20] - Loss: 1.1122 - Accuracy: 80.62%
# Epoch [8/20] - Loss: 1.2100 - Accuracy: 80.28%
# Epoch [9/20] - Loss: 0.8902 - Accuracy: 84.38%
# Epoch [10/20] - Loss: 0.9196 - Accuracy: 85.56%
# Epoch [11/20] - Loss: 0.6399 - Accuracy: 87.64%
# Epoch [12/20] - Loss: 0.6291 - Accuracy: 85.83%
# Epoch [13/20] - Loss: 0.5173 - Accuracy: 88.75%
# Epoch [14/20] - Loss: 0.4473 - Accuracy: 90.62%
# Epoch [15/20] - Loss: 0.3150 - Accuracy: 92.22%
# Epoch [16/20] - Loss: 0.3743 - Accuracy: 91.39%
# Epoch [17/20] - Loss: 0.4518 - Accuracy: 90.14%
# Epoch [18/20] - Loss: 0.4459 - Accuracy: 89.86%
# Epoch [19/20] - Loss: 0.4737 - Accuracy: 91.67%
# Epoch [20/20] - Loss: 0.5517 - Accuracy: 90.07%

# %%
from sklearn.metrics import classification_report
from torch.utils.data import DataLoader

# Define val_loader_triple
final_val_ds = TripleModalityDataset(val_df, '/content/Kaggle_Prepared')
val_loader_triple = DataLoader(final_val_ds, batch_size=16, shuffle=False)

model_final.eval()
y_true, y_pred = [], []

with torch.no_grad():
    for rgb, ms, hs, labels in val_loader_triple:
        rgb, ms, hs = rgb.to(device), ms.to(device), hs.to(device)
        outputs = model_final(rgb, ms, hs)
        _, predicted = torch.max(outputs, 1)
        y_true.extend(labels.numpy())
        y_pred.extend(predicted.cpu().numpy())

print(classification_report(y_true, y_pred, target_names=["Health", "Rust", "Other"]))
# Out:
#               precision    recall  f1-score   support
#
#       Health       0.98      0.67      0.79       120
#         Rust       0.79      0.98      0.88       120
#        Other       0.88      0.94      0.91       120
#
#     accuracy                           0.86       360
#    macro avg       0.88      0.86      0.86       360
# weighted avg       0.88      0.86      0.86       360

# %%
from sklearn.model_selection import StratifiedKFold
import numpy as np

from torch.optim.lr_scheduler import CosineAnnealingLR

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
fold_results = []

labels = df['label'].map({"Health": 0, "Rust": 1, "Other": 2}).values

print(f" Fold Cross-Validation on triple fusion ")

for fold, (train_idx, val_idx) in enumerate(skf.split(df, labels)):
    print(f"\n#️ Fold {fold+1}/5")

    train_df_fold = df.iloc[train_idx]
    val_df_fold = df.iloc[val_idx]

    train_ds = TripleModalityDataset(train_df_fold, '/content/Kaggle_Prepared')
    val_ds = TripleModalityDataset(val_df_fold, '/content/Kaggle_Prepared')

    train_loader = DataLoader(train_ds, batch_size=16, shuffle=True)
    val_loader = DataLoader(val_ds, batch_size=16, shuffle=False)

    model_fold = TripleFusionModel().to(device)
    optimizer = torch.optim.Adam(model_fold.parameters(), lr=0.0001)
    criterion = nn.CrossEntropyLoss()



    scheduler = CosineAnnealingLR(optimizer, T_max=20) # لـ 20 Epochs

    for epoch in range(20):
        model_fold.train()
        running_loss = 0.0
        for rgb, ms, hs, target in train_loader:
            rgb, ms, hs, target = rgb.to(device), ms.to(device), hs.to(device), target.to(device)

            optimizer.zero_grad()
            output = model_fold(rgb, ms, hs)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()

        scheduler.step()
        print(f"Epoch {epoch+1}/20 - Loss: {running_loss/len(train_loader):.4f}")

    model_fold.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for rgb, ms, hs, target in val_loader:
            rgb, ms, hs, target = rgb.to(device), ms.to(device), hs.to(device), target.to(device)
            output = model_fold(rgb, ms, hs)
            _, pred = torch.max(output, 1)
            total += target.size(0)
            correct += (pred == target).sum().item()

    fold_acc = 100. * correct / total
    fold_results.append(fold_acc)
    print(f"Fold {fold+1} Accuracy: {fold_acc:.2f}%")

print(f"\5 Folds mean accuracy: {np.mean(fold_results):.2f}% (+/- {np.std(fold_results):.2f})")
# Out:
#  Fold Cross-Validation on triple fusion
#
# #️ Fold 1/5
# Epoch 1/20 - Loss: 7.6232
# Epoch 2/20 - Loss: 5.3233
# Epoch 3/20 - Loss: 5.4658
# Epoch 4/20 - Loss: 4.1931
# Epoch 5/20 - Loss: 3.5390
# Epoch 6/20 - Loss: 3.0252
# Epoch 7/20 - Loss: 3.0636
# Epoch 8/20 - Loss: 2.4231
# Epoch 9/20 - Loss: 1.5968
# Epoch 10/20 - Loss: 2.0620
# Epoch 11/20 - Loss: 1.9038
# Epoch 12/20 - Loss: 1.3986
# Epoch 13/20 - Loss: 0.7271
# Epoch 14/20 - Loss: 0.7385
# Epoch 15/20 - Loss: 0.4659
# Epoch 16/20 - Loss: 0.3955
# Epoch 17/20 - Loss: 0.3462
# Epoch 18/20 - Loss: 0.3288
# Epoch 19/20 - Loss: 0.2964
# Epoch 20/20 - Loss: 0.2829
# Fold 1 Accuracy: 85.83%
#
# #️ Fold 2/5
# Epoch 1/20 - Loss: 8.3790
# Epoch 2/20 - Loss: 5.6990
# Epoch 3/20 - Loss: 5.3626
# Epoch 4/20 - Loss: 5.6809
# Epoch 5/20 - Loss: 3.4610
# Epoch 6/20 - Loss: 2.6433
# Epoch 7/20 - Loss: 2.2793
# Epoch 8/20 - Loss: 2.1022
# Epoch 9/20 - Loss: 2.0141
# Epoch 10/20 - Loss: 1.6625
# Epoch 11/20 - Loss: 2.0198
# Epoch 12/20 - Loss: 0.8369
# Epoch 13/20 - Loss: 0.8793
# Epoch 14/20 - Loss: 0.6762
# Epoch 15/20 - Loss: 0.4338
# Epoch 16/20 - Loss: 0.3675
# Epoch 17/20 - Loss: 0.2735
# Epoch 18/20 - Loss: 0.3086
# Epoch 19/20 - Loss: 0.2766
# Epoch 20/20 - Loss: 0.2252
# Fold 2 Accuracy: 89.17%
#
# #️ Fold 3/5
# Epoch 1/20 - Loss: 9.2869
# Epoch 2/20 - Loss: 3.0040
# Epoch 3/20 - Loss: 2.2198
# Epoch 4/20 - Loss: 2.7053
# Epoch 5/20 - Loss: 2.7803
# Epoch 6/20 - Loss: 2.3016
# Epoch 7/20 - Loss: 2.0283
# Epoch 8/20 - Loss: 1.8167
# Epoch 9/20 - Loss: 1.5795
# Epoch 10/20 - Loss: 1.4666
# Epoch 11/20 - Loss: 1.2045
# Epoch 12/20 - Loss: 0.6920
# Epoch 13/20 - Loss: 0.6943
# Epoch 14/20 - Loss: 0.4466
# Epoch 15/20 - Loss: 0.3640
# Epoch 16/20 - Loss: 0.3146
# Epoch 17/20 - Loss: 0.2735
# Epoch 18/20 - Loss: 0.2757
# Epoch 19/20 - Loss: 0.2485
# Epoch 20/20 - Loss: 0.2262
# Fold 3 Accuracy: 90.56%
#
# #️ Fold 4/5
# Epoch 1/20 - Loss: 17.0984
# Epoch 2/20 - Loss: 3.1569
# Epoch 3/20 - Loss: 2.4026
# Epoch 4/20 - Loss: 1.8203
# Epoch 5/20 - Loss: 1.5699
# Epoch 6/20 - Loss: 1.2306
# Epoch 7/20 - Loss: 1.1615
# Epoch 8/20 - Loss: 1.2696
# Epoch 9/20 - Loss: 0.8919
# Epoch 10/20 - Loss: 0.6409
# Epoch 11/20 - Loss: 0.7791
# Epoch 12/20 - Loss: 0.5075
# Epoch 13/20 - Loss: 0.3825
# Epoch 14/20 - Loss: 0.3449
# Epoch 15/20 - Loss: 0.2938
# Epoch 16/20 - Loss: 0.2530
# Epoch 17/20 - Loss: 0.2277
# Epoch 18/20 - Loss: 0.2160
# Epoch 19/20 - Loss: 0.2005
# Epoch 20/20 - Loss: 0.2134
# Fold 4 Accuracy: 92.50%
#
# #️ Fold 5/5
# Epoch 1/20 - Loss: 9.9729
# Epoch 2/20 - Loss: 5.9945
# Epoch 3/20 - Loss: 4.9314
# Epoch 4/20 - Loss: 4.2919
# Epoch 5/20 - Loss: 3.1337
# Epoch 6/20 - Loss: 2.8357
# Epoch 7/20 - Loss: 2.0666
# Epoch 8/20 - Loss: 3.2512
# Epoch 9/20 - Loss: 2.0597
# Epoch 10/20 - Loss: 1.2147
# Epoch 11/20 - Loss: 1.1558
# Epoch 12/20 - Loss: 0.7491
# Epoch 13/20 - Loss: 0.7892
# Epoch 14/20 - Loss: 0.6615
# Epoch 15/20 - Loss: 0.4195
# Epoch 16/20 - Loss: 0.3973
# Epoch 17/20 - Loss: 0.3285
# Epoch 18/20 - Loss: 0.2859
# Epoch 19/20 - Loss: 0.3152
# Epoch 20/20 - Loss: 0.2768
# Fold 5 Accuracy: 88.89%
#  Folds mean accuracy: 89.39% (+/- 2.19)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


cm = np.array([
    [80,  35,   5],  
    [ 1, 117,   2],  
    [ 4,   6, 110]   
])

classes = ["Health", "Rust", "Other"]


plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Greens', 
            xticklabels=classes, yticklabels=classes)

plt.title('Confusion Matrix - TripleFusionModel (Final Validation Fold)')
plt.ylabel('Actual Label')
plt.xlabel('Predicted Label')
plt.show()

# %%
torch.save(model_fold.state_dict(), 'Wheat_TripleFusion_Final_Model.pth')
